# %% [markdown]
# # 0. Повторение — мать учения
# ✍ В этом модуле нам понадобятся знания основных статистических терминов и типов визуализации. Предлагаем вам освежить их в памяти ↓
#
# ### Задание 0.1
# Мода — это…
# - наименее встречающееся значение в данных
# - середина распределения
# - наиболее распространённое значение в данных верно
# - 50-ая квантиль

# %% [markdown]
# ### Задание 0.2
# С помощью какого метода можно производить встроенную визуализацию в библиотеке pandas?
# - value_counts()
# - drop()
# - plot() верно
# - draw()

# %% [markdown]
# ### Задание 0.3
# Выберите верное описание тепловой карты:
# - Тепловая карта — график, представляющий собой визуализацию распределения признака. Весь интервал разделяется на  равных частей. На каждом интервале строится прямоугольник, высота которого равна числу попавших в интервал наблюдений.
# - Тепловая карта — график, представляющий собой круг, разбитый на секторы, каждый из которых является частью общего круга.
# - Тепловая карта — график, представляющий собой визуализацию табличных данных. Каждая ячейка помечается определённым цветом, который зависит от значения в ячейке. верно
# - Тепловая карта — график, представляющий собой линию, соединяющую точки в декартовой системе координат.

# %% [markdown]
# ### Задание 0.4
# Перед вами гистограмма распределения числа мигрантов в странах во всем мире за 2020 год. Укажите все верные утверждения.
#
# ![](img/dst-3-unit-1-mod-14-1.png)
#
# 1. Диапазон изменения числа мигрантов от -2 до 2 миллионов.
# 2. В основной массе стран миграция отсутствует, либо ее значение близко к 0.
# 3. Из гистограммы видно примерно одинаковое соотношение эмигрантов и иммигрантов в мире.
# 4. Основная масса стран имеет в среднем около 200 тысяч эммигрантов.
#
# Ответ: 2, 3

# %% [markdown]
# ### Задание 0.5
# Перед вами — коробчатая диаграмма. Соотнесите отметки на графике и статистические параметры, которым они соответствуют.
#
# ![](img/dst-3-unit-1-mod-14-2.png)
#
# 1. IQR — межквартильный размах
# 2. Q25 — 25-ый квантиль
# 3. медиана
# 4. Q75 — 75-ый квантиль
# 5. MIN — условный минимум распределения
# 6. MAX — условный максимум распределения
