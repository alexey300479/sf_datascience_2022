# %% [markdown]
# # 0. Повторение — мать учения
#  Добавить страницу в мои закладки
# ✍ Предлагаем вам повторить ранее изученный материал, ответив на несколько вопросов ↓
#
# ### Задание 0.1
# Какой метод позволяет производить группировку данных по одному или нескольким признакам?
# - groupby() верно
# - sort_values()
# - merge()
# - grouped()

# %% [markdown]
# ### Задание 0.2
# Какой параметр метода pivot_table() отвечает за вычисляемую агрегирующую функцию?
# - index
# - aggfunc верно
# - aggmethod
# - aggregate
#
# Ответ
#
# Верно:Данный параметр предназначен для выбора агрегирующей функции, которая будет вычисляться при группировке сводной таблицы.

# %% [markdown]
# ### Задание 0.3
# Ниже изображены таблицы left и right, а также результат их объединения. Для объединения использовался метод merge(). А какой тип объединения был указан?
#
# ![](./img/dst3-u1-md13_0_1.png)
#
# - inner
# - left
# - right
# - outer верно
#
# Ответ
#
# Верно:Так как в объединение попали все ключи из всех таблиц, то в качестве типа объединения был выбран outer.
