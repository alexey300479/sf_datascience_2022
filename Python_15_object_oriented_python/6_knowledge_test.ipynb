# %% [markdown]
# # 6. Проверка знаний
# ### Задание 6.1
#
# У вас есть класс DataBase, где метод __init__ принимает один аргумент. Какой код создаст объект этого класса и положит его в переменную db?
#
# ``` python
# db = DataBase()
# ```
# ### Задание 6.2
# Чем отличается метод от обычной функции? Выберите все верные варианты.
# - Метод определяется для класса, функция — сама по себе. верно
# - Функция определяется для класса, метод — сам по себе.
# - Метод первым аргументом получает вызывающий его объект. верно
# - В метод первым аргументом мы должны передавать вызывающий его объект.
# ### Задание 6.3
#
# Определите класс Dog, у которого есть методы bark и give_paw.
# - bark возвращает строку "Bark!"
# - give_paw возвращает строку "Paw"
#
# ``` python
# class Dog():
#     def bark(self):
#         return 'Bark!'
#
#     def give_paw(self):
#         return 'Paw'
# ```
#
# ### Задание 6.4
# В папке animals в файле dog.py лежит класс Dog. Напишите команду, которая импортирует этот класс.
#
# ``` python
# from animals.dog import Dog
# ```
